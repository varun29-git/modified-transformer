# %%
# !pip install -q tiktoken datasets tqdm tensorboard
# !git clone -q https://github.com/varun29-git/modified-transformer.git
# %cd modified-transformer
# Out:
# /nlsasfs/home/aikosh/prod-aikosh03/modified-transformer

# %%
import torch
device = torch.cuda.get_device_name(0)
vram = torch.cuda.get_device_properties(0).total_memory / 1e9
print(f"GPU: {device} | VRAM: {vram:.1f}GB")
# Out:
# GPU: NVIDIA A100-SXM4-40GB MIG 1g.5gb | VRAM: 5.1GB

# %%
# !python train.py
# Out:
# Loaded 50000 stories
# Sample story:
# One day, a little girl named Lily found a needle in her room. She knew it was difficult to play with it because it was sharp. Lily wanted to share the needle with her mom, so she could sew a button on...
#
# Using device: cuda
# Vocabulary size: 100277
# Training samples: 78413
# Validation samples: 4128
# Model parameters: 56,176,309
#
# ...
# Epoch 1/10
# ...
# Validation: 100%|█████████████| 516/516 [00:27<00:00, 18.55it/s, val_loss=3.903]
# Validation Loss: 3.7682 | Perplexity: 43.30
# Learning Rate: 0.000293
# Checkpoint saved: weights/checkpoint_00.pt
# ✓ New best model saved! Val Loss: 3.7682
#
# ...
# Epoch 2/10
# ...
# Validation: 100%|█████████████| 516/516 [00:27<00:00, 18.69it/s, val_loss=3.733]
# Validation Loss: 3.5716 | Perplexity: 35.57
# Learning Rate: 0.000271
# Checkpoint saved: weights/checkpoint_01.pt
# ✓ New best model saved! Val Loss: 3.5716
#
# ...
# Epoch 3/10
# ...
# Validation: 100%|█████████████| 516/516 [00:32<00:00, 15.93it/s, val_loss=3.632]
# ...
